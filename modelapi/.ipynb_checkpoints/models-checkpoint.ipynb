# %%
# !pip install unidecode
# !pip install neattext
# !pip install numpy
# !pip install pandas
# !pip install seaborn
# !pip install seaborn
# !pip install sklearn

import numpy as np
import pandas as pd
import seaborn as sns
import neattext.functions as nfx
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import re
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from unidecode import unidecode
from sklearn.preprocessing import LabelEncoder

# def clean_text(x):
#   x_ascii =unidecode(x)
#   x_clean=special_character_removal.sub(' ',x_ascii)
#   return x_clean 
  

# train_df=pd.read_csv('/content/drive/MyDrive/abc.csv')
# train_df=pd.read_csv('/content/drive/MyDrive/datasetbefitfinal (1).csv')
train_df=pd.read_csv('updatedbefit.csv')

print(train_df['sentiment'].value_counts())
sns.countplot(x='sentiment',data=train_df)
train_df.head(10)
data= train_df.loc[:,['content','sentiment']]


# special_character_removal=re.compile(r'[^a-zA-Z\.\-\?\!\,\#\...\%]',re.IGNORECASE)
# data['clean_text']= data['content'].apply(lambda x:clean_text(str(x)))
# data['clean_text']=data['clean_text'].fillna('empty')



train_df['clean_text'] = train_df['content'].apply(nfx.remove_userhandles)
train_df['clean_text'] = train_df['content'].apply(nfx.remove_stopwords)
x=train_df['clean_text']
target=data['sentiment']
y=target
# y=data['sentiment']
# data.head(10)
# le_inputPartA = LabelEncoder()
# y = data['sentiment'].apply(le_inputPartA.fit_transform)
# x=data.iloc[:,2]
# y=data.iloc[:,1]

x_train, x_test, y_train, y_test = train_test_split(x.values,y.values,test_size=0.2,random_state=42)

#text_clf=Pipeline([('vect',CountVectorizer()),('tfidf',TfidfTransformer()),('clf',MultinomialNB())])
text_clf=Pipeline([('vect',CountVectorizer()),('tfidf',TfidfTransformer()),('lr',LogisticRegression())])
text_clf.fit(x_train,y_train)


import pickle
import gzip
filename="ss.sav"
f=open(filename,'wb')
pickle.dump(text_clf,f)
f.close()

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
predictions = text_clf.predict(x_test)
print(confusion_matrix(y_test,predictions))
print('Accuracy Score',accuracy_score(y_test,predictions)*100,'%')

#print('Accuracy Score',text_clf.score(x_test,y_test))


#insonmina
# ex1 = "I do not sleep"

# social media addiction
# ex1 = "i use whatsapp all the time everywhere i go"
# ex1 = "i use whatsapp most of the time"
# ex1 = "i use facebook most of the time"
# ex1="i become moody, restless, irritable or depressed when i stop or decrease  Internet use"

#hate
# ex1="i dont like hamza"
# ex1="i am feellng attacked or threatened evertime from people"
# ex1="i feel jeausealy because of people's success"

#fear
# ex1=" i am afraid of to jump from balconi"
# ex1="i am afraid brcause i always thinking about arslan will kill me"
# ex1=" I am afraid of swimming"
# ex1="I am frightend of leaving alone  house"


# angry  
ex1="I am furious that I failed my exam"

#sad
# ex1= "feeling sad unable to describe myself"

print(text_clf.predict([ex1]))
print(text_clf.predict_proba([ex1]))
print(text_clf.classes_)





from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
prec = metrics.precision_score(y_test, predictions,average='micro')
print("Precision for multiclassnavie base :",prec)
recall = metrics.recall_score(y_test, predictions,average='micro')
print("Recall for Multiclass Navie base:",recall)
Fmeasure = (2*prec*recall)/(prec+recall)
print("The F-Measure Multiclass Navie base is: ",Fmeasure)

cnf_matrix = metrics.confusion_matrix(y_test,predictions)

fp_nb = cnf_matrix.sum(axis=0) - np.diag(cnf_matrix)  
fn_nb = cnf_matrix.sum(axis=1) - np.diag(cnf_matrix)
tp_nb = np.diag(cnf_matrix)
tn_nb = cnf_matrix.sum() - (fp_nb + fp_nb + fp_nb)

fp_nb = fp_nb.astype(float)
fn_nb = fn_nb.astype(float)
tp_nb = tp_nb.astype(float)
tn_nb = tn_nb.astype(float)

TPR_nb = tp_nb/(tp_nb+fn_nb)
tpr_nb =0
for i in TPR_nb:
  tpr_nb +=i
tpr_nb = tpr_nb/len(TPR_nb)   
print("True Positive rate for naive bayes is: ", tpr_nb)  


FPR_nb = fp_nb/(fp_nb+tn_nb)
fpr_nb =0
for i in FPR_nb:
  fpr_nb +=i
fpr_nb = fpr_nb/len(FPR_nb)
print("False Positive rate for naive bayes is: ", fpr_nb)  

from matplotlib import pyplot as plt
plt.figure(figsize=(5,5),dpi=100)
plt.plot(FPR_nb,TPR_nb,marker='.',label='ROC')
plt.xlabel('False positive Rate')
plt.ylabel('True positive Rate')
plt.legend()
plt.show()

sns.heatmap(confusion_matrix(y_test,predictions), annot=True, cmap='Blues')
# Out:
# Requirement already satisfied: unidecode in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (1.3.2)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: neattext in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (0.1.2)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: numpy in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (1.21.4)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: pandas in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (1.3.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: pandas>=0.23 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: numpy>=1.15 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: scipy>=1.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: six>=1.5 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.23->seaborn) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Requirement already satisfied: setuptools in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (41.2.0)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: scipy>=1.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.7.3)
# Requirement already satisfied: matplotlib>=2.2 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (3.5.0)
# Requirement already satisfied: numpy>=1.15 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: pandas>=0.23 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: cycler>=0.10 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (6.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (4.28.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (3.0.6)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: pytz>=2017.3 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (1.2.2)
# Requirement already satisfied: setuptools in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from setuptools-scm>=4->matplotlib>=2.2->seaborn) (41.2.0)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: sklearn in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (3.0.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.1.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/mac/Documents/GitHub/modelflask/venv/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# WARNING: You are using pip version 19.2.3, however version 21.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# hate           268
# insomnia       259
# sadness        172
# anger           99
# fear            98
# socialMedia     81
# Name: sentiment, dtype: int64
# [[12  0  6  0  0  0]
#  [ 0 10 13  0  0  0]
#  [ 0  0 49  1  2  0]
#  [ 0  0  4 45  0  0]
#  [ 0  0 17  1 20  2]
#  [ 0  0  0  0  2 12]]
# Accuracy Score 75.51020408163265 %
# ['anger']
# [[0.47076376 0.07532039 0.17433713 0.11976152 0.1219945  0.03782269]]
# ['anger' 'fear' 'hate' 'insomnia  ' 'sadness' 'socialMedia']
#               precision    recall  f1-score   support
#
#        anger       1.00      0.67      0.80        18
#         fear       1.00      0.43      0.61        23
#         hate       0.55      0.94      0.70        52
#   insomnia         0.96      0.92      0.94        49
#      sadness       0.83      0.50      0.62        40
#  socialMedia       0.86      0.86      0.86        14
#
#     accuracy                           0.76       196
#    macro avg       0.87      0.72      0.75       196
# weighted avg       0.83      0.76      0.75       196
#
# Precision for multiclassnavie base : 0.7551020408163265
# Recall for Multiclass Navie base: 0.7551020408163265
# The F-Measure Multiclass Navie base is:  0.7551020408163265
# True Positive rate for naive bayes is:  0.7198778619586071
# False Positive rate for naive bayes is:  0.06448958588081846
# <AxesSubplot:>
